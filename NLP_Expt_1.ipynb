# %% [markdown]
# <a href="https://colab.research.google.com/github/jagilisreeja/NLP-Exp-1/blob/main/NLP_Expt_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punk_tab')
# Out:
# [nltk_data] Error loading punk_tab: Package 'punk_tab' not found in
# [nltk_data]     index
# False

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
nltk.download('punkt')
nltk.download('punkt_tab') # Added as per error recommendation
input = "Hi iam sreeja.How are you"
output = word_tokenize(input)
print(output)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Hi', 'iam', 'sreeja.How', 'are', 'you']

# %%
output = sent_tokenize(input)
print(output)
# Out:
# ['Hi iam sreeja.How are you']

# %%
# !pip install spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
input = "This is the second session"
doc = nlp(input)
for token in doc:
  print(token)
# Out:
# This
# is
# the
# second
# session
